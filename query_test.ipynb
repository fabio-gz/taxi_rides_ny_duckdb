# %%
import duckdb
import pandas as pd

# %%
conn = duckdb.connect(database='nyc_taxi.duckdb', read_only=False)

# %%
df = conn.execute("select * from green_tripdata limit 5").df()

# %%
df
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2021-12-02 08:28:59   2021-12-02 08:35:54                  N
# 1         2  2021-12-03 08:31:48   2021-12-03 08:53:42                  N
# 2         2  2021-12-03 13:42:12   2021-12-03 14:15:19                  N
# 3         2  2021-12-04 17:20:52   2021-12-04 17:31:39                  N
# 4         2  2021-12-04 18:40:07   2021-12-04 18:58:32                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            24            41              1.0           0.80
# 1         1.0            42           236              1.0           2.86
# 2         1.0           166           233              1.0           6.45
# 3         1.0           236           141              1.0           1.63
# 4         1.0            75           141              4.0           2.61
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# ...

# %%
df2 = conn.execute("select * from fact_trips limit 5").df()
df2
# Out:
#                              tripid  vendorid service_type  ratecodeid  \
# 0  6ab9ab0954d06f1124338d9de438cf52         1        Green           1
# 1  43af171111d5b061bcd253d284f0de8e         1        Green           1
# 2  7640bb4e82453b7cfc4b0abdec1267b5         1        Green           1
# 3  31b24f29abb4b3b56561a41cad3a617a         1        Green           1
# 4  8be723fe7ec6ea5fd342e7cae5b1d5fc         1        Green           1
#
#    pickup_locationid pickup_borough               pickup_zone  \
# 0                166      Manhattan       Morningside Heights
# 1                244      Manhattan  Washington Heights South
# 2                 82         Queens                  Elmhurst
# 3                 74      Manhattan         East Harlem North
# 4                173         Queens              North Corona
#
#    dropoff_locationid dropoff_borough           dropoff_zone  ... extra  \
# 0                 238       Manhattan  Upper West Side North  ...  2.75
# ...
